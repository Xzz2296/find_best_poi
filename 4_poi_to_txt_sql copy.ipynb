# %% [markdown]
# # 数据载入

# %%
import pandas as pd
import os
from collections import Counter
import numpy as np

import torch

# %%
pd.set_option('display.max_colwidth', -1)
# Out:
# C:\Users\c'y'y\AppData\Local\Temp\ipykernel_7768\3652881321.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
poi_path =r'E:\xpj\research\POI\psqlcsv\losangeles.csv'
poi_prompt_path =r'E:\xpj\research\POI\result\losangeles_poi_prompt.xlsx'
image_path = r'E:\xpj\research\POI\psqlcsv\losangeles_img_location.csv'
image_poi_path = r'E:\xpj\research\POI\psqlcsv\losangeles_img_poi.csv'
# desc_path =r'E:\xpj\research\POI\desc_merge\losangeles_desc_merged.csv'
desc_path =r'E:\xpj\research\POI\desc_clean\los\Losangeles_desc_clean_2.xlsx'
best_poi_path = r'E:\xpj\research\POI\result\losangeles_best_poi.xlsx'
desc_poi_path = r'E:\xpj\research\POI\result\losangeles_desc_poi_1.xlsx'

# %% [markdown]
# ## poi数据（全面）

# %%
poi_data = pd.read_csv(poi_path,encoding='utf-8')
# poi_data = pd.read_csv(r"E:\xpj\research\POI\mumbai_poi.csv",encoding='ANSI')
poi_df = pd.DataFrame(poi_data)
# Out:
# d:\software\Anaconda\envs\clip\lib\site-packages\IPython\core\interactiveshell.py:3269: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
poi_df
# Out:
#             id                                                geom  \
# 0       1       0101000020E6100000A81485A721985DC03B037EE8DDFA4040
# 1       2       0101000020E6100000FC03E5B67D9B5DC05396218E75034140
# 2       3       0101000020E61000005994C8F43A9B5DC032F3D36EAA034140
# 3       4       0101000020E6100000BF4868CBB99A5DC087B8832227044140
# 4       5       0101000020E6100000E3361AC05B925DC038B984E8B5044140
# ...    ..                                                      ...
# 374485  374486  0101000020E61000002CDC4D4B079B5DC04EA89663681C4140
# 374486  374487  0101000020E6100000B2CC6CA1759A5DC0BB1A8F087C1D4140
# 374487  374488  0101000020E610000044E7902F7C9A5DC0D2318C60881D4140
# 374488  374489  0101000020E6100000F0EEB72C159A5DC0DA65AEC21C1E4140
# 374489  374490  0101000020E61000009477C4D70D9A5DC00AE7093A101E4140
#
#              osm_id name barrier            highway  ref address is_in place  \
# 0       653656       NaN  NaN     traffic_signals    NaN  NaN     NaN   NaN
# 1       653688       NaN  NaN     traffic_signals    NaN  NaN     NaN   NaN
# 2       653689       NaN  NaN     traffic_signals    NaN  NaN     NaN   NaN
# 3       653693       NaN  NaN     traffic_signals    NaN  NaN     NaN   NaN
# 4       653731       NaN  NaN     motorway_junction  13A  NaN     NaN   NaN
# ...        ...       ...  ...                   ...  ...  ...     ...   ...
# 374485  11498186894  NaN  gate    NaN                NaN  NaN     NaN   NaN
# 374486  11498186913  NaN  gate    NaN                NaN  NaN     NaN   NaN
# 374487  11498186918  NaN  gate    NaN                NaN  NaN     NaN   NaN
# 374488  11498186935  NaN  gate    NaN                NaN  NaN     NaN   NaN
# 374489  11498186977  NaN  gate    NaN                NaN  NaN     NaN   NaN
#
#        man_made                   other_tags
# 0       NaN      "traffic_signals"=>"signal"
# 1       NaN      NaN
# 2       NaN      NaN
# 3       NaN      "traffic_signals"=>"signal"
# 4       NaN      NaN
# ...     ...      ...
# 374485  NaN      NaN
# 374486  NaN      NaN
# 374487  NaN      NaN
# 374488  NaN      NaN
# 374489  NaN      NaN
#
# [374490 rows x 12 columns]

# %%
poi_df.columns
# Out:
# Index(['id', 'geom', 'osm_id', 'name', 'barrier', 'highway', 'ref', 'address',
#        'is_in', 'place', 'man_made', 'other_tags'],
#       dtype='object')

# %% [markdown]
#  # 下面第一块可以不做

# %%
# save tag list to txt

# poi_df_nec=poi_df.loc[:,['id', 'name', 'barrier', 'highway','ref', 'address', 'place', 'man_made', 'other_tags']]
# poi_df_ot =poi_df_nec.loc[:,['other_tags']]
# tag_list = []
# def collect_tags(x):
#     # print(x['other_tags'])
    
#     if  pd.notna(x['other_tags']):
#         # print(x['other_tags'])
#         tags = x['other_tags'].split("\",\"")
#         # print(tags)
#         for tag in tags:
#             try:
#                 tag = tag.replace("\"","")
#                 t = tag.split("=>")[0]
#                 if t not in tag_list:
#                     tag_list.append(t)
#             except:
#                 pass
#     # return tag_list

# result = poi_df_ot.apply(lambda x: collect_tags(x), axis=1, result_type='expand')
# # result
# tag_list.sort()
# tag_list
# # 保存tag_list到txt
# with open(r'E:\xpj\research\POI\chennai_tag_list.txt', 'w') as f:
#     for item in tag_list:
#         f.write("%s\n" % item)

# poi_df_ot

# def genSent(x):
#     tags = None
#     b = True    
#     # sen = "The imformation of this point contains that "
#     sen = "Nearby,"
#     for key in ['name','barrier', 'highway','address','place','man_made']:
#         if not x[key].isna().iloc[0]:
#             # print(x[key])
#             sen = sen + key +" is " + x[key].iloc[0] + ","
#     if not x['other_tags'].isna().iloc[0]:
#         tags = x['other_tags'].iloc[0].split("\",\"")
#         for tag in tags:
#             try:
#                 tag = tag.replace("\"","")
#                 t = tag.split("=>")[0]
#                 k = tag.split("=>")[1]
#                 if "name:" in t and t != "name:en":
#                     pass
#                 sen = sen + t +" is " + k + ","
#             except:
#                 pass

#     sen = sen + "located in " + x['NAME_2'].iloc[0]
    
#     # return sen,b
    
#     return sen
# # poi_df_nec

# %% [markdown]
# ## 照片信息

# %%
pic_data = pd.read_csv(image_path,encoding='utf-8')
# pic_data = pd.read_csv(r"E:\xpj\research\POI\mumbai_points.csv",encoding='ANSI')
pic_df = pd.DataFrame(pic_data)

# %%
pic_df
# Out:
#             id                                                geom  \
# 0       1       0101000020E6100000A37C9CC4FB9D5DC0C21B2D6233FD4040
# 1       2       0101000020E6100000D3B947DB1D965DC02757676B33F74040
# 2       3       0101000020E61000003673486A21965DC0FB3BDBA337F74040
# 3       4       0101000020E6100000405475EA25965DC02E3DF5A33CF74040
# 4       5       0101000020E61000008B975DE62A965DC0CCDA5CEB41F74040
# ...    ..                                                      ...
# 467281  467282  0101000020E6100000800F5EBBB48C5DC0DBAFF14F5FE94040
# 467282  467283  0101000020E61000006C64B213B98C5DC0803EDBB463E94040
# 467283  467284  0101000020E6100000ABB7616FBD8C5DC0B98C9B1A68E94040
# 467284  467285  0101000020E6100000024DDFC6C18C5DC06953758F6CE94040
# 467285  467286  0101000020E61000002F63AF1CC68C5DC04399FC0571E94040
#
#                      captured_a camera_mak               created_at  \
# 0       2019/12/31 17:21:50.377  Apple      2020/01/16 12:33:34.106
# 1       2019/12/30 23:16:48.038  Apple      2019/12/31 06:47:06.213
# 2       2019/12/30 23:16:48.038  Apple      2019/12/31 06:47:06.213
# 3       2019/12/30 23:16:48.038  Apple      2019/12/31 06:47:06.213
# 4       2019/12/30 23:16:48.038  Apple      2019/12/31 06:47:06.213
# ...                         ...    ...                          ...
# 467281  2019/06/22 19:57:45.000  waylens    2019/08/23 00:28:53.720
# 467282  2019/06/22 19:57:45.000  waylens    2019/08/23 00:28:53.720
# 467283  2019/06/22 19:57:45.000  waylens    2019/08/23 00:28:53.720
# 467284  2019/06/22 19:57:45.000  waylens    2019/08/23 00:28:53.720
# 467285  2019/06/22 19:57:45.000  waylens    2019/08/23 00:28:53.720
#
#                     sequences_  pano                user_key    username  \
# 0       DJLcqZ_ZY_gaJF7-qlgxmA  0     -2mefvRi_q4Z8GmsMNpzEA  sunhine2
# 1       amy28hziqt7lmtz63lyhww  0     LPyfXwYHyYdxZ9e9Wl004g  doperopeco
# 2       amy28hziqt7lmtz63lyhww  0     LPyfXwYHyYdxZ9e9Wl004g  doperopeco
# 3       amy28hziqt7lmtz63lyhww  0     LPyfXwYHyYdxZ9e9Wl004g  doperopeco
# 4       amy28hziqt7lmtz63lyhww  0     LPyfXwYHyYdxZ9e9Wl004g  doperopeco
# ...                        ... ..                        ...         ...
# 467281  w0ikihrghn9aaloxru2b1d  0     Awq3cRgINTKBIsW7ieabuQ  mds08011
# 467282  w0ikihrghn9aaloxru2b1d  0     Awq3cRgINTKBIsW7ieabuQ  mds08011
# 467283  w0ikihrghn9aaloxru2b1d  0     Awq3cRgINTKBIsW7ieabuQ  mds08011
# 467284  w0ikihrghn9aaloxru2b1d  0     Awq3cRgINTKBIsW7ieabuQ  mds08011
# 467285  w0ikihrghn9aaloxru2b1d  0     Awq3cRgINTKBIsW7ieabuQ  mds08011
#
#                        img_key       ca   longitude   latitude
# 0       DNqUckyDOxum715vsoWkWA  252.319 -118.468492  33.978131
# 1       CYJTNws78c3cWzDH5mopog  300.986 -118.345572  33.931257
# 2       1n7ETkn_ts-ZgzulPNpfKg  306.119 -118.345789  33.931385
# 3       njPA5univBJDCHEKSBYDgw  302.380 -118.346064  33.931538
# 4       Otga57VtFBNhvE5H2ENC-A  302.646 -118.346368  33.931699
# ...                        ...      ...         ...        ...
# 467281  BGxkKBYxn080yfZINWgevU  301.250 -118.198531  33.823221
# 467282  JnLsRl-R3oiEtHfsWEzumH  301.250 -118.198796  33.823355
# 467283  rmfDdmCx0mUmIK8WDEp83F  301.210 -118.199062  33.823490
# 467284  z2xY1mS07b8duAj4zUU688  301.810 -118.199327  33.823625
# 467285  mqbiqphQU4xSldiVVrjldV  301.730 -118.199592  33.823762
#
# [467286 rows x 13 columns]

# %% [markdown]
# ## 照片poi关联

# %%
pic_poi_data = pd.read_csv(image_poi_path,encoding='utf-8')
# pic_poi_data = pd.read_csv(r"E:\xpj\research\POI\mumbai_pois_to_points.csv",encoding='ANSI')
pic_poi_df = pd.DataFrame(pic_poi_data)

# %%
pic_poi_df
# Out:
#                        img_key     id1  distance1       id2   distance2  \
# 0       ---5zkU1EfJ6wuRILp-ybQ  155619  44.550862  79358.0   97.794584
# 1       ---VmA8yoknvwu8YkhJfCg  361691  76.699781  218738.0  80.607283
# 2       --_o16-deXQza7ufPTgUzQ  115384  92.808760  115383.0  113.272981
# 3       --0jEYBjHsuxZePWv2feJA  336633  12.429786  155169.0  30.243773
# 4       --0z7fxPPdc66jn9IziALg  102645  48.296023  531.0     58.191628
# ...                        ...     ...        ...    ...           ...
# 467272  zZZo9T5-0F2kINGiF2qynA  78781   66.164163  369027.0  91.465357
# 467273  ZzZSlzKhqgYX6NXBOx-Rwg  32545   75.183561  32546.0   78.034724
# 467274  zZzsq2VZ2BXqvyYA6TkDUA  198319  20.233160  198320.0  62.608599
# 467275  zZzuqIFjI1MAB962-vcTvA  64365   6.607542   64364.0   21.878861
# 467276  zzzVgDpIZ95T337KvhK2vA  241370  61.061846  343493.0  61.153399
#
#              id3   distance3       id4   distance4       id5   distance5
# 0       155621.0  120.173460  155620.0  127.092754  370656.0  208.339138
# 1       218737.0  81.333501   203072.0  159.432536  42052.0   195.964865
# 2       327349.0  116.895819  335536.0  120.391338  54172.0   128.195921
# 3       123242.0  35.443421   187391.0  61.635056   187388.0  64.926337
# 4       89713.0   84.896562   332220.0  105.002080  347622.0  133.848449
# ...         ...         ...        ...         ...       ...         ...
# 467272  203654.0  146.249356  155639.0  166.130358  197405.0  182.590204
# 467273  53138.0   138.536543  21766.0   156.339221  259705.0  211.745409
# 467274  198253.0  98.173608   198325.0  129.240387  49561.0   140.133306
# 467275  64366.0   87.889648   178465.0  106.417322  178453.0  132.656759
# 467276  241373.0  82.950839   241371.0  84.456904   268061.0  86.175932
#
# [467277 rows x 11 columns]

# %% [markdown]
# ## 照片描述

# %%
# desc_pd =pd.read_csv(desc_path,encoding='utf-8')
desc_pd =pd.read_excel(desc_path)
desc_pd
# Out:
#                            key  \
# 0       BJPPRPAED_P1ZEY3e-Uv-Q
# 1       6F0er_SaMb5zsNkfbdsGMA
# 2       ZPj3oxW7UJm9i_DcfOHHlg
# 3       gAPbml8Bl0a1XRlflHVWug
# 4       z-Fldhni3kG3y_6ixSAdcQ
# ...                        ...
# 680180  YWg5AGPV3QbuVoGzPEDAFA
# 680181  yUvwYhfj20CqVMtqn5xWBw
# 680182  IZ3uDKUi8oMPf2hob3tJcg
# 680183  -D9wH3iEFZWd74GwDOg9RA
# 680184  4329oBdLeC1XlS7HFHzIjw
#
#                                                                                                                                                                                                                                        prompt
# 0       arafed view of a street with a stop sign and a car, a matte painting inspired by Elbridge Ayer Burbank, polycount, superflat, 1600 south azusa avenue, beautiful panoramic imagery, photorealistic streetscape
# 1       arafed view of a residential neighborhood with a street and a street light, a tilt shift photo inspired by Elbridge Ayer Burbank, polycount, precisionism, 1600 south azusa avenue, beautiful panoramic imagery, gardena architecture
# 2       arafed view of a car parked on a street corner with a stop sign, a matte painting by Elbridge Ayer Burbank, polycount, american scene painting, equirectangular, 360 monoscopic equirectangular, found on google street view
# 3       arafed view of a street with palm trees and a house, a detailed matte painting inspired by Elbridge Ayer Burbank, polycount, american realism, 1600 south azusa avenue, beautiful panoramic imagery, gardena architecture
# 4       there is a car that is parked on the side of the street, a matte painting inspired by Elbridge Ayer Burbank, polycount, superflat, 1600 south azusa avenue, found on google street view, wide angle shot 4 k hdr
# ...                                                                                                                                                                                                                  ...
# 680180  cars driving on a highway with a billboard on the side of it, a matte painting by Elbridge Ayer Burbank, tumblr, precisionism, electronic billboards, digital billboard in the middle, high traffic
# 680181  there is a view of a street from a vehicle window, a photo by L. A. Ring, featured on tumblr, superflat, view from a news truck, unobstructed road, 1600 south azusa avenue
# 680182  cars parked on the side of the road in a residential area, a matte painting inspired by Elbridge Ayer Burbank, tumblr contest winner, superflat, eyelevel perspective image, unobstructed road, 1600 south azusa avenue
# 680183  arafed view of a street with cars driving down it, a matte painting by Elbridge Ayer Burbank, featured on cg society, precisionism, driving through a 1 9 5 0 s town, 1600 south azusa avenue, wide-angle lens vanishing point
# 680184  cars driving on a highway with a truck in the background, a matte painting by Elbridge Ayer Burbank, featured on reddit, stuckism, police cars, gta v gameplay screenshot, flying emergency vehicles
#
# [680185 rows x 2 columns]

# %% [markdown]
# # 数据处理

# %% [markdown]
# ## poi数据预处理

# %%
poi_df_nec=poi_df.loc[:,['id', 'name', 'barrier', 'highway', 'address', 'place', 'man_made', 'other_tags']]

# %%
poi_df_nec
# Out:
#             id name barrier            highway address place man_made  \
# 0       1       NaN  NaN     traffic_signals    NaN     NaN   NaN
# 1       2       NaN  NaN     traffic_signals    NaN     NaN   NaN
# 2       3       NaN  NaN     traffic_signals    NaN     NaN   NaN
# 3       4       NaN  NaN     traffic_signals    NaN     NaN   NaN
# 4       5       NaN  NaN     motorway_junction  NaN     NaN   NaN
# ...    ..       ...  ...                   ...  ...     ...   ...
# 374485  374486  NaN  gate    NaN                NaN     NaN   NaN
# 374486  374487  NaN  gate    NaN                NaN     NaN   NaN
# 374487  374488  NaN  gate    NaN                NaN     NaN   NaN
# 374488  374489  NaN  gate    NaN                NaN     NaN   NaN
# 374489  374490  NaN  gate    NaN                NaN     NaN   NaN
#
#                          other_tags
# 0       "traffic_signals"=>"signal"
# 1       NaN
# 2       NaN
# 3       "traffic_signals"=>"signal"
# 4       NaN
# ...     ...
# 374485  NaN
# 374486  NaN
# 374487  NaN
# 374488  NaN
# 374489  NaN
#
# [374490 rows x 8 columns]

# %%
# poi_df_nec.to_csv(r"E:\xpj\research\POI\poi_df_nec.csv")

# %% [markdown]
# # 硬提示计算相似度，找最佳poi

# %%
from transformers import AutoTokenizer, AutoModel
import torch
import numpy as np

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# print("device:", device)

# 加载BERT模型和分词器
tokenizer = AutoTokenizer.from_pretrained(r"E:\xpj\models\bert-base-uncased")
model = AutoModel.from_pretrained(r"E:\xpj\models\bert-base-uncased")
# model.to(device)

# %%
# 定义计算相似度的函数
def calc_similarity(s1, s2):
    # 对句子进行分词，并添加特殊标记
    inputs = tokenizer([s1, s2], return_tensors='pt', padding=True, truncation=True)
    # inputs.to(device)
    # print(inputs)

    # 将输入传递给BERT模型，并获取输出
    with torch.no_grad():
        outputs = model(**inputs)
        embeddings = outputs.last_hidden_state[:, 0, :].cpu().numpy()

    # 计算余弦相似度，并返回结果
    sim = np.dot(embeddings[0], embeddings[1]) / (np.linalg.norm(embeddings[0]) * np.linalg.norm(embeddings[1]))
    return sim

# %%
def isEnglish(s):
    if isinstance(s, str):
        return s.isascii()
    return False



# 从txt中读取tag_list
tag_ignore_list = []
with open(r'E:\xpj\research\POI\tag_ignore_list.txt', 'r') as f:
    for line in f.readlines():
        tag_ignore_list.append(line.strip())
# print(tag_ignore_list)

def genSent(x):
    tags = None
    b = True    
    # sen = "The imformation of this point contains that "
    sen = "Nearby,"
    for key in ['name','barrier', 'highway','address','place','man_made']:
        if isinstance(x[key],str) and not isEnglish(x[key]):
            continue
        # # 北京保留中文
        # if key == 'name' and not isEnglish(x['name'].iloc[0]):
        #     continue
        if not x[key].isna().iloc[0]:
            # print(x[key])
            sen = sen + key +" is " + x[key].iloc[0] + ","
    # print(sen)
    if not x['other_tags'].isna().iloc[0]:
        tags = x['other_tags'].iloc[0].split("\",\"")
        for tag in tags:
            try:
                tag = tag.replace("\"","")
                t = tag.split("=>")[0]
                k = tag.split("=>")[1]
                # 北京保留中文
                if not isEnglish(k) or not isEnglish(t):
                    print(k,t)
                    continue
                if list(t)[-1] == "=":
                    continue
                if t in tag_ignore_list:
                    continue
                # if "name:" in t and t != "name:en":
                #     pass
                # pass 的作用是什么也不做 跳过，continue的作用是执行下次for循环
                # print(t,k)
                sen = sen + t +" is " + k + ","
            except:
                pass

    # sen = sen + "located in " + x['NAME_2'].iloc[0]
    
    # return sen,b
    
    return sen

# %%
# a="脿陇陇脿陇戮脿陇聹脿陇庐脿陇鹿脿陇戮脿陇脿陇陋脿楼聟脿陇虏脿楼聡脿陇脿陇鹿脿楼聣脿陇聼脿楼聡脿陇"
# # print(isEnglish(a))
# b="à¤­à¤¾à¤°à¤¤à¥à¤à¤¹à¤µà¤¾à¤®à¤¾à¤¨ à¤µà¤¿à¤­à¤¾à¤"
# print(isEnglish(b))
# print(b.encode('utf-8').decode('ISO-8859-1'))
# s = "啶ぞ啶班い啷€啶啶灌さ啶距ぎ啶距え 啶掂た啶ぞ啶"
# print(s.encode('ansi').decode('iscii'))

# %% [markdown]
# 将poi对应的自然语言提示存储到文件中(poi_nec最后插入一列提示)

# %%
def store_poi(x):
    # print(x)
    poi = x[0]
    # print(poi)    
    poi_im = poi_df_nec.loc[poi_df_nec['id']==poi]
    sen = genSent(poi_im)
    return sen
    # print(sen)

# %%
from tqdm import tqdm
result =[]
for index, row in tqdm(poi_df_nec.iterrows(), total=poi_df_nec.shape[0], desc="Processing"):
    # if index == 130:
    #     print(store_poi(row))
    result.append(store_poi(row))
# result = poi_df_nec.apply(lambda x: store_poi(x), axis=1, result_type='expand')
# poi_df_nec['poi_prompt']= result
# poi_df_nec['poi_prompt'] = result

# %%
import pandas as pd
print(pd.options)

# %%
# poi_df_nec.to_csv(r"E:\xpj\research\POI\poi_df_nec3.csv")
poi_df_nec['poi_prompt'] = result
poi_df_nec.to_excel(poi_prompt_path)
# poi_df_nec.to_csv(poi_prompt_path)

# %%
poi_df_nec =pd.read_excel(poi_prompt_path)
poi_df_nec
# Out:
#         Unnamed: 0      id name barrier            highway address place  \
# 0       0           1       NaN  NaN     traffic_signals    NaN     NaN
# 1       1           2       NaN  NaN     traffic_signals    NaN     NaN
# 2       2           3       NaN  NaN     traffic_signals    NaN     NaN
# 3       3           4       NaN  NaN     traffic_signals    NaN     NaN
# 4       4           5       NaN  NaN     motorway_junction  NaN     NaN
# ...    ..          ..       ...  ...                   ...  ...     ...
# 374485  374485      374486  NaN  gate    NaN                NaN     NaN
# 374486  374486      374487  NaN  gate    NaN                NaN     NaN
# 374487  374487      374488  NaN  gate    NaN                NaN     NaN
# 374488  374488      374489  NaN  gate    NaN                NaN     NaN
# 374489  374489      374490  NaN  gate    NaN                NaN     NaN
#
#        man_made                   other_tags  \
# 0       NaN      "traffic_signals"=>"signal"
# 1       NaN      NaN
# 2       NaN      NaN
# 3       NaN      "traffic_signals"=>"signal"
# 4       NaN      NaN
# ...     ...      ...
# 374485  NaN      NaN
# 374486  NaN      NaN
# 374487  NaN      NaN
# 374488  NaN      NaN
# 374489  NaN      NaN
#
#                                                           poi_prompt
# 0       Nearby,highway is traffic_signals,traffic_signals is signal,
# 1       Nearby,highway is traffic_signals,
# 2       Nearby,highway is traffic_signals,
# 3       Nearby,highway is traffic_signals,traffic_signals is signal,
# 4       Nearby,highway is motorway_junction,
# ...                                      ...
# 374485  Nearby,barrier is gate,
# 374486  Nearby,barrier is gate,
# 374487  Nearby,barrier is gate,
# 374488  Nearby,barrier is gate,
# 374489  Nearby,barrier is gate,
#
# [374490 rows x 10 columns]

# %%
def find_best_poi(x):
    # print(x)
    img_key = x['img_key']
    # img_file = img_key+'.jpg'
    img_file =img_key
    try:
        img_desc = desc_pd.loc[desc_pd['key']==img_file]['prompt'].iloc[0]
    except:
        print("The description of picture " + img_file +" doesn't exist")
        return  None,None
    pois = x[1::2]
    pois_dis =x[2::2]
    # print(pois)
    similarities = []
    sentences = []
    for index,poi in enumerate(pois):
        # 设置距离阈值
        if pois_dis[index] is not None and pois_dis[index]<100:

            # # 根据id从poi_df_nec中找到poi_prompt
            try:
                sen = poi_df_nec.loc[poi_df_nec['id']==poi]['poi_prompt'].iloc[0]
            except Exception as e:
                print(e)
                print("The poi_prompt of poi " + poi +" doesn't exist")
                continue
            
            # poi_im = poi_df_nec.loc[poi_df_nec['id']==poi]
            # sen = genSent(poi_im)
            # try:
            # # 检查 DataFrame 是否为空
            #     sen = poi_df_nec.loc[poi_df_nec['id']==poi]['poi_prompt'].iloc[0]
            #     # 在此处理 sen 的其他操作

            # except Exception as e:
            #     print(e)
            #     # print("An error occurred while processing poi " + poi)
            #     continue

        
            similarity = calc_similarity(img_desc,sen)
            sentences.append(sen)
            similarities.append(similarity)
        
    if len(similarities) == 0:
        best_poi=None
        return best_poi,0
    elif similarities and max(similarities)>0.5:
        best_poi = pois[similarities.index(max(similarities))]
        return best_poi,max(similarities)

# %%
result = []
for _, row in tqdm(pic_poi_df.iterrows(), total=pic_poi_df.shape[0], desc="Processing"):
    result.append(find_best_poi(row))

# pic_poi_df[['best_poi', 'best_poi_score']] = result

# %%
result

# %%
result
result_df = pd.DataFrame(result,columns=['best_poi','best_poi_score']) # 将列表转换成DataFrame
pic_poi_df = pic_poi_df.join(result_df) # 将新的DataFrame添加到原始DataFrame中
# pic_poi_df.shape[0]

# %%
# 上一块做了，这一块就不做了
#result = pic_poi_df.apply(lambda x: find_best_poi(x), axis=1,result_type='expand')

# %%
#pic_poi_df[['best_poi','similarity']]= result

# %%
# 从本地读取poi_df_nec
pic_poi_df =pd.read_excel(best_poi_path)

# %%
pic_poi_df
# Out:
#         Unnamed: 0                 img_key     id1  distance1       id2  \
# 0       0           ---5zkU1EfJ6wuRILp-ybQ  155619  44.550862  79358.0
# 1       1           ---VmA8yoknvwu8YkhJfCg  361691  76.699781  218738.0
# 2       2           --_o16-deXQza7ufPTgUzQ  115384  92.808760  115383.0
# 3       3           --0jEYBjHsuxZePWv2feJA  336633  12.429786  155169.0
# 4       4           --0z7fxPPdc66jn9IziALg  102645  48.296023  531.0
# ...    ..                              ...     ...        ...    ...
# 467272  467272      zZZo9T5-0F2kINGiF2qynA  78781   66.164163  369027.0
# 467273  467273      ZzZSlzKhqgYX6NXBOx-Rwg  32545   75.183561  32546.0
# 467274  467274      zZzsq2VZ2BXqvyYA6TkDUA  198319  20.233160  198320.0
# 467275  467275      zZzuqIFjI1MAB962-vcTvA  64365   6.607542   64364.0
# 467276  467276      zzzVgDpIZ95T337KvhK2vA  241370  61.061846  343493.0
#
#          distance2       id3   distance3       id4   distance4       id5  \
# 0       97.794584   155621.0  120.173460  155620.0  127.092754  370656.0
# 1       80.607283   218737.0  81.333501   203072.0  159.432536  42052.0
# 2       113.272981  327349.0  116.895819  335536.0  120.391338  54172.0
# 3       30.243773   123242.0  35.443421   187391.0  61.635056   187388.0
# 4       58.191628   89713.0   84.896562   332220.0  105.002080  347622.0
# ...           ...       ...         ...        ...         ...       ...
# 467272  91.465357   203654.0  146.249356  155639.0  166.130358  197405.0
# 467273  78.034724   53138.0   138.536543  21766.0   156.339221  259705.0
# 467274  62.608599   198253.0  98.173608   198325.0  129.240387  49561.0
# 467275  21.878861   64366.0   87.889648   178465.0  106.417322  178453.0
# 467276  61.153399   241373.0  82.950839   241371.0  84.456904   268061.0
#
#          distance5  best_poi  best_poi_score
# 0       208.339138  79358.0   0.768555
# 1       195.964865  218738.0  0.822145
# 2       128.195921  115384.0  0.786609
# 3       64.926337   155169.0  0.826188
# 4       133.848449  102645.0  0.867430
# ...            ...       ...       ...
# 467272  182.590204  369027.0  0.778231
# 467273  211.745409  32546.0   0.820567
# 467274  140.133306  198320.0  0.843566
# 467275  132.656759  64365.0   0.789082
# 467276  86.175932   241370.0  0.853699
#
# [467277 rows x 14 columns]

# %%
pic_poi_df.to_excel(best_poi_path)

# %%
df1 = pd.merge(pic_poi_df, poi_df_nec, left_on="best_poi",right_on = 'id',how="left")

# %%
# df1 =pd.read_excel(best_poi_path)

# %%
df1
# Out:
#         Unnamed: 0_x                 img_key     id1  distance1       id2  \
# 0       0             ---5zkU1EfJ6wuRILp-ybQ  155619  44.550862  79358.0
# 1       1             ---VmA8yoknvwu8YkhJfCg  361691  76.699781  218738.0
# 2       2             --_o16-deXQza7ufPTgUzQ  115384  92.808760  115383.0
# 3       3             --0jEYBjHsuxZePWv2feJA  336633  12.429786  155169.0
# 4       4             --0z7fxPPdc66jn9IziALg  102645  48.296023  531.0
# ...    ..                                ...     ...        ...    ...
# 467272  467272        zZZo9T5-0F2kINGiF2qynA  78781   66.164163  369027.0
# 467273  467273        ZzZSlzKhqgYX6NXBOx-Rwg  32545   75.183561  32546.0
# 467274  467274        zZzsq2VZ2BXqvyYA6TkDUA  198319  20.233160  198320.0
# 467275  467275        zZzuqIFjI1MAB962-vcTvA  64365   6.607542   64364.0
# 467276  467276        zzzVgDpIZ95T337KvhK2vA  241370  61.061846  343493.0
#
#          distance2       id3   distance3       id4   distance4  ...  \
# 0       97.794584   155621.0  120.173460  155620.0  127.092754  ...
# 1       80.607283   218737.0  81.333501   203072.0  159.432536  ...
# 2       113.272981  327349.0  116.895819  335536.0  120.391338  ...
# 3       30.243773   123242.0  35.443421   187391.0  61.635056   ...
# 4       58.191628   89713.0   84.896562   332220.0  105.002080  ...
# ...           ...       ...         ...        ...         ...  ...
# 467272  91.465357   203654.0  146.249356  155639.0  166.130358  ...
# 467273  78.034724   53138.0   138.536543  21766.0   156.339221  ...
# 467274  62.608599   198253.0  98.173608   198325.0  129.240387  ...
# 467275  21.878861   64366.0   87.889648   178465.0  106.417322  ...
# 467276  61.153399   241373.0  82.950839   241371.0  84.456904   ...
#
#         Unnamed: 0_y        id  name  barrier  highway  address place  \
# 0       79357.0       79358.0   NaN   NaN      NaN      NaN      NaN
# 1       218737.0      218738.0  NaN   gate     NaN      NaN      NaN
# 2       115383.0      115384.0  NaN   NaN      NaN      NaN      NaN
# 3       155168.0      155169.0  NaN   gate     NaN      NaN      NaN
# 4       102644.0      102645.0  NaN   NaN      NaN      NaN      NaN
# ...          ...           ...  ...   ...      ...      ...      ...
# 467272  369027.0      369027.0  NaN   NaN      NaN      NaN      NaN
# 467273  32545.0       32546.0   NaN   gate     NaN      NaN      NaN
# 467274  198319.0      198320.0  NaN   NaN      NaN      NaN      NaN
# 467275  64364.0       64365.0   NaN   NaN      stop     NaN      NaN
# 467276  241369.0      241370.0  NaN   gate     NaN      NaN      NaN
#
#        man_made                                     other_tags  \
# 0       NaN      "leisure"=>"playground"
# 1       NaN      NaN
# 2       NaN      "power"=>"pole"
# 3       NaN      NaN
# 4       NaN      "amenity"=>"drinking_water"
# ...     ...                              ...
# 467272  NaN      "direction"=>"both","traffic_calming"=>"hump"
# 467273  NaN      "access"=>"no"
# 467274  NaN      "traffic_calming"=>"hump"
# 467275  NaN      NaN
# 467276  NaN      NaN
#
#                                                poi_prompt
# 0       Nearby,leisure is playground,
# 1       Nearby,barrier is gate,
# 2       Nearby,power is pole,
# 3       Nearby,barrier is gate,
# 4       Nearby,amenity is drinking_water,
# ...                                   ...
# 467272  Nearby,direction is both,traffic_calming is hump,
# 467273  Nearby,barrier is gate,
# 467274  Nearby,traffic_calming is hump,
# 467275  Nearby,highway is stop,
# 467276  Nearby,barrier is gate,
#
# [467277 rows x 24 columns]

# %%
# df1.to_excel(best_poi_path)

# %%
poi_df_nec.columns
# Out:
# Index(['Unnamed: 0', 'id', 'name', 'barrier', 'highway', 'address', 'place',
#        'man_made', 'other_tags', 'poi_prompt'],
#       dtype='object')

# %%
# desc_pd: file,prompt insert poi_prompt
# df1 : image_key, bestpoi
# poi_df_nec: FID ,poi_prompt
def connect(x):
    image_file_name = x[0]
    image_name =image_file_name.split('.')[0]
    best_poi_row = df1.loc[df1['img_key']==image_name]['best_poi']
    best_poi = None
    if best_poi_row.notna().any():
        best_poi=int(best_poi_row.iloc[0])
        poi_prompt = poi_df_nec.loc[poi_df_nec['id']==best_poi]['poi_prompt'].iloc[0]
        return poi_prompt
        # print(poi_prompt)
    # print(best_poi)
    # print("\n")
    

    # print(image_name)

# %%
result2 = desc_pd.apply(lambda x: connect(x), axis=1,result_type='expand')
result2
# Out:
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
#           ...
# 680180    None
# 680181    None
# 680182    None
# 680183    None
# 680184    None
# Length: 680185, dtype: object

# %%
desc_pd['poi_prompt'] = result2

# %%
desc_pd
# Out:
#                            key  \
# 0       BJPPRPAED_P1ZEY3e-Uv-Q
# 1       6F0er_SaMb5zsNkfbdsGMA
# 2       ZPj3oxW7UJm9i_DcfOHHlg
# 3       gAPbml8Bl0a1XRlflHVWug
# 4       z-Fldhni3kG3y_6ixSAdcQ
# ...                        ...
# 680180  YWg5AGPV3QbuVoGzPEDAFA
# 680181  yUvwYhfj20CqVMtqn5xWBw
# 680182  IZ3uDKUi8oMPf2hob3tJcg
# 680183  -D9wH3iEFZWd74GwDOg9RA
# 680184  4329oBdLeC1XlS7HFHzIjw
#
#                                                                                                                                                                                                                                        prompt  \
# 0       arafed view of a street with a stop sign and a car, a matte painting inspired by Elbridge Ayer Burbank, polycount, superflat, 1600 south azusa avenue, beautiful panoramic imagery, photorealistic streetscape
# 1       arafed view of a residential neighborhood with a street and a street light, a tilt shift photo inspired by Elbridge Ayer Burbank, polycount, precisionism, 1600 south azusa avenue, beautiful panoramic imagery, gardena architecture
# 2       arafed view of a car parked on a street corner with a stop sign, a matte painting by Elbridge Ayer Burbank, polycount, american scene painting, equirectangular, 360 monoscopic equirectangular, found on google street view
# 3       arafed view of a street with palm trees and a house, a detailed matte painting inspired by Elbridge Ayer Burbank, polycount, american realism, 1600 south azusa avenue, beautiful panoramic imagery, gardena architecture
# 4       there is a car that is parked on the side of the street, a matte painting inspired by Elbridge Ayer Burbank, polycount, superflat, 1600 south azusa avenue, found on google street view, wide angle shot 4 k hdr
# ...                                                                                                                                                                                                                  ...
# 680180  cars driving on a highway with a billboard on the side of it, a matte painting by Elbridge Ayer Burbank, tumblr, precisionism, electronic billboards, digital billboard in the middle, high traffic
# 680181  there is a view of a street from a vehicle window, a photo by L. A. Ring, featured on tumblr, superflat, view from a news truck, unobstructed road, 1600 south azusa avenue
# 680182  cars parked on the side of the road in a residential area, a matte painting inspired by Elbridge Ayer Burbank, tumblr contest winner, superflat, eyelevel perspective image, unobstructed road, 1600 south azusa avenue
# 680183  arafed view of a street with cars driving down it, a matte painting by Elbridge Ayer Burbank, featured on cg society, precisionism, driving through a 1 9 5 0 s town, 1600 south azusa avenue, wide-angle lens vanishing point
# 680184  cars driving on a highway with a truck in the background, a matte painting by Elbridge Ayer Burbank, featured on reddit, stuckism, police cars, gta v gameplay screenshot, flying emergency vehicles
#
#        poi_prompt
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# ...      ...
# 680180  None
# 680181  None
# 680182  None
# 680183  None
# 680184  None
#
# [680185 rows x 3 columns]

# %%
desc_pd.to_excel(desc_poi_path)
